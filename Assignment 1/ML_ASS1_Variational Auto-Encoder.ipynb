# %%
from keras.models import Sequential 
from keras.layers import Dense,Conv2D,MaxPooling2D,UpSampling2D
from keras import Input, Model
from keras.datasets import mnist
from keras import backend as k
from keras.layers import Lambda
from tensorflow.keras.metrics import binary_crossentropy
import keras


import numpy as np
import matplotlib.pyplot as plt
import random

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 784)
# (10000, 784)

# %%
batch_size, n_epoch = 100, 150
latent_dim = 2

input_img = Input(shape=(x_train[0].shape))
x = Dense(200, activation='relu')(input_img)
x= Dense(100, activation='relu')(x)
x = Dense(30, activation='relu')(x)

mu = Dense(latent_dim)(x)
log_var = Dense(latent_dim)(x)

encoder = Model(input_img, mu, name='Encoder')
encoder.summary()
# Out:
# Model: "Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense (Dense)               (None, 200)               157000
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 30)                3030
#
#  dense_3 (Dense)             (None, 2)                 62
#
# =================================================================
# Total params: 180,192
# Trainable params: 180,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sampling(args):
    mu, log_var = args
    eps = k.random_normal(shape=(batch_size, latent_dim), mean=0., stddev=1.0)
    return mu + k.exp(log_var) * eps

z = Lambda(sampling, output_shape=(latent_dim,))([mu, log_var])

# %%
z_decoder1 = Dense(30, activation='relu')
z_decoder2 = Dense(100, activation='relu')
z_decoder3 = Dense(200, activation='relu')
y_decoder = Dense((x_train[0].shape[0]), activation='sigmoid')

z_decoded = z_decoder1(z)
z_decoded = z_decoder2(z_decoded)
z_decoded = z_decoder3(z_decoded)
y = y_decoder(z_decoded)

# %%
reconstruction_loss = binary_crossentropy(input_img, y) * x_train[0].shape
kl_loss = 0.5 * k.sum(k.square(mu) + k.exp(log_var) - log_var - 1, axis = -1)
vae_loss = reconstruction_loss + kl_loss

vae = Model(input_img, y)
vae.add_loss(vae_loss)

vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 784)]        0           []
#
#  dense (Dense)                  (None, 200)          157000      ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 100)          20100       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 30)           3030        ['dense_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 2)            62          ['dense_2[0][0]']
#
#  lambda (Lambda)                (100, 2)             0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
#  dense_5 (Dense)                (100, 30)            90          ['lambda[0][0]']
#
#  dense_6 (Dense)                (100, 100)           3100        ['dense_5[0][0]']
#
#  dense_7 (Dense)                (100, 200)           20200       ['dense_6[0][0]']
#
#  dense_8 (Dense)                (100, 784)           157584      ['dense_7[0][0]']
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['dense_3[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 2)            0           ['dense_4[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.square[0][0]',
#  da)                                                              'tf.math.exp[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 784)          0           ['input_1[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (100, 784)          0           ['dense_8[0][0]']
#  da)
#
#  tf.math.subtract (TFOpLambda)  (None, 2)            0           ['tf.__operators__.add[0][0]',
#                                                                   'dense_4[0][0]']
#
#  tf.keras.backend.binary_crosse  (100, 784)          0           ['tf.cast[0][0]',
#  ntropy (TFOpLambda)                                              'tf.convert_to_tensor[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (100,)              0           ['tf.keras.backend.binary_crossen
#  a)                                                              tropy[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (100,)               0           ['tf.math.reduce_mean[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (100,)              0           ['tf.math.multiply[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  add_loss (AddLoss)             (100,)               0           ['tf.__operators__.add_1[0][0]']
#
# ==================================================================================================
# Total params: 361,228
# Trainable params: 361,228
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.compile(optimizer='rmsprop')
history = vae.fit(x_train, shuffle=True, epochs=n_epoch, batch_size=batch_size, validation_data=(x_test, None), verbose=1)
# Out:
# Epoch 1/150
# 600/600 [==============================] - 17s 22ms/step - loss: 193.2686 - val_loss: 167.3536
# Epoch 2/150
# 600/600 [==============================] - 9s 15ms/step - loss: 162.1746 - val_loss: 157.1999
# Epoch 3/150
# 600/600 [==============================] - 8s 14ms/step - loss: 155.6088 - val_loss: 153.4996
# Epoch 4/150
# 600/600 [==============================] - 8s 14ms/step - loss: 151.8016 - val_loss: 150.4030
# Epoch 5/150
# 600/600 [==============================] - 8s 14ms/step - loss: 149.2886 - val_loss: 148.0424
# Epoch 6/150
# 600/600 [==============================] - 9s 14ms/step - loss: 147.5379 - val_loss: 146.9338
# Epoch 7/150
# 600/600 [==============================] - 9s 15ms/step - loss: 146.2356 - val_loss: 145.7542
# Epoch 8/150
# 600/600 [==============================] - 9s 16ms/step - loss: 144.7143 - val_loss: 144.4850
# Epoch 9/150
# 600/600 [==============================] - 9s 15ms/step - loss: 143.3840 - val_loss: 143.8936
# Epoch 10/150
# 600/600 [==============================] - 9s 14ms/step - loss: 142.7246 - val_loss: 143.2208
# Epoch 11/150
# 600/600 [==============================] - 9s 15ms/step - loss: 141.9225 - val_loss: 141.7114
# Epoch 12/150
# 600/600 [==============================] - 10s 17ms/step - loss: 141.7369 - val_loss: 141.6818
# Epoch 13/150
# 600/600 [==============================] - 8s 14ms/step - loss: 140.4709 - val_loss: 140.1873
# Epoch 14/150
# 600/600 [==============================] - 10s 17ms/step - loss: 140.0612 - val_loss: 139.3840
# Epoch 15/150
# 600/600 [==============================] - 9s 14ms/step - loss: 139.7653 - val_loss: 140.0513
# Epoch 16/150
# 600/600 [==============================] - 8s 14ms/step - loss: 139.2432 - val_loss: 138.9161
# Epoch 17/150
# 600/600 [==============================] - 9s 14ms/step - loss: 138.6145 - val_loss: 139.2326
# Epoch 18/150
# Epoch 133/150
# 600/600 [==============================] - 8s 14ms/step - loss: 136.5839 - val_loss: 137.7652
# Epoch 134/150
# 600/600 [==============================] - 9s 15ms/step - loss: 135.8587 - val_loss: 137.2835
# Epoch 135/150
# 600/600 [==============================] - 9s 14ms/step - loss: 136.2227 - val_loss: 137.3445
# Epoch 136/150
# 600/600 [==============================] - 9s 14ms/step - loss: 135.9463 - val_loss: 139.8887
# Epoch 137/150
# 600/600 [==============================] - 8s 14ms/step - loss: 136.7510 - val_loss: 138.2971
# Epoch 138/150
# 600/600 [==============================] - 9s 14ms/step - loss: 136.2567 - val_loss: 138.1037
# Epoch 139/150
# 600/600 [==============================] - 8s 14ms/step - loss: 136.2303 - val_loss: 138.8823
# Epoch 140/150
# 600/600 [==============================] - 9s 15ms/step - loss: 136.1330 - val_loss: 136.8869
# Epoch 141/150
# 600/600 [==============================] - 9s 14ms/step - loss: 136.2112 - val_loss: 137.0058
# Epoch 142/150
# 600/600 [==============================] - 9s 14ms/step - loss: 135.8680 - val_loss: 138.4022
# Epoch 143/150
# 600/600 [==============================] - 8s 14ms/step - loss: 135.9837 - val_loss: 138.5874
# Epoch 144/150
# 600/600 [==============================] - 9s 14ms/step - loss: 136.8614 - val_loss: 138.0981
# Epoch 145/150
# 600/600 [==============================] - 9s 14ms/step - loss: 136.2117 - val_loss: 137.5985
# Epoch 146/150
# 600/600 [==============================] - 8s 14ms/step - loss: 135.9125 - val_loss: 137.3988
# Epoch 147/150
# 600/600 [==============================] - 8s 14ms/step - loss: 135.7285 - val_loss: 138.0000
# Epoch 148/150
# 600/600 [==============================] - 8s 14ms/step - loss: 136.0608 - val_loss: 137.4935
# Epoch 149/150
# 600/600 [==============================] - 9s 15ms/step - loss: 135.9425 - val_loss: 138.8674
# Epoch 150/150
# 600/600 [==============================] - 9s 15ms/step - loss: 135.5430 - val_loss: 137.0538

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss Vs Epoch')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.show()

# %%
x_te_latent = encoder.predict(x_test, batch_size=256)
plt.figure(figsize=(6, 6))
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], c=y_test)
plt.colorbar()
plt.show()

# %%
decoded_img = vae.predict(x_test, batch_size=batch_size)

# %%
n = 10

print('Orignal Image:')
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()


print('Reconstructed Image:')
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_img[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Orignal Image:
# Reconstructed Image:

# %%
decoder_input = Input(shape=(latent_dim,))
_z_decoded = z_decoder1(decoder_input)
_z_decoded = z_decoder2(_z_decoded)
_z_decoded = z_decoder3(_z_decoded)
_y = y_decoder(_z_decoded)
generator = Model(decoder_input, _y, name='Decoder')
generator.summary()
# Out:
# Model: "Decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_5 (Dense)             multiple                  90
#
#  dense_6 (Dense)             multiple                  3100
#
#  dense_7 (Dense)             multiple                  20200
#
#  dense_8 (Dense)             multiple                  157584
#
# =================================================================
# Total params: 180,974
# Trainable params: 180,974
# Non-trainable params: 0
# _________________________________________________________________

# %%
from scipy.stats import norm

n = 15
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = norm.ppf(np.linspace(0.05, 0.95, n)) 
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
